# %%
from PIL import Image
import pytesseract

# %%
img = Image.open("./cooper-4_1.png")

# %%
text = pytesseract.image_to_string(img, lang = 'eng')

# %%
img
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGB size=833x798 at 0x7F042B13C8D0>

# %%
print(text)

# %%
filepath = "Approach to the synthesis of the C1–C11 and C14–C18 portion of Leucascandrolide A - Organic Chemistry Frontiers (RSC Publishing) DOI_10.1039_C6QO00284F_files"
filename = "c6qo00284f-s3.gif"
homepath = "../html"

# try:
#     img = Image.open(homepath + "/" + filepath + "/" + filename)
#     rgb_im = img.convert('RGB')
#     img_jpg.save(filename[:-4] + '.jpg')
    
# except:
#     print("123")
    
    
img_1 = Image.open(homepath + "/" + filepath + "/" + filename)
rgb_im = img.convert('RGB')
rgb_im.save(homepath + "/" + filepath + "/" + filename[:-4] + '.jpg', 'JPEG')

img_1 = Image.open(homepath + "/" + filepath + "/" + filename[:-4] + '.jpg')

# %%
text = pytesseract.image_to_string(img_1, lang = 'eng')

# %%
img_1
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=367x347 at 0x7FF3ECDD0F60>

# %%
print(text)
# Out:
# mas auy‘Mgc!
#
# W”
# N u
#
# 9 m = «.2
# (syn/mm
#
#
#
#
#
# mm.
#
# L7 alumna:
# mas cup, 4m
#
# ”MW-W
# cum, / 95‘”
#
#
#
# ON 0 0 was dr=t1
# (mama
